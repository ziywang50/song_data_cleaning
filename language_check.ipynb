# %%
import pandas as pd
import langdetect as lg

# %%
original_data = pd.read_csv("output/data/song_data_rows_needed_to_check.csv")

# %%
pd.set_option('display.max_rows', 500)
original_data
# Out:
#      Unnamed: 0               artist  \
# 0           265        Aiza Seguerra
# 1           268        Aiza Seguerra
# 2           269        Aiza Seguerra
# 3           271        Aiza Seguerra
# 4           273        Aiza Seguerra
# 5           553       Andrea Bocelli
# 6          1269             Boney M.
# 7          1273             Boney M.
# 8          1537         Carol Banawa
# 9          1540         Carol Banawa
# 10         1948      Christina Perri
# 11         2103        Cliff Richard
# 12         2117        Cliff Richard
# 13         2621          Dean Martin
# 14         2677          Deep Purple
# 15         2839              Dewa 19
# 16         2840              Dewa 19
# 17         2841              Dewa 19
# 18         2842              Dewa 19
# 19         3468        Elvis Presley
# 20         3579               Enigma
# 21         3580               Enigma
# 22         3600     Enrique Iglesias
# 23         3601     Enrique Iglesias
# ...

# %%
#select rows in English
rows_to_remove = [11, 13, 14, 20, 107, 116, 124, 135, 201, 257]

# %%
dropped_data = original_data.drop(rows_to_remove)

# %% [markdown]
# co = 0
# list_of_rows = []
# for index, row in enumerate(original_data['text']):
#     co+=1
#     print("index", index)
#     print('text', row)
#     list_of_rows.append(index)
# print("count=", co)

# %%
indices_to_drop = dropped_data['Unnamed: 0']

# %%
indices_to_drop = list(indices_to_drop)

# %%
len(indices_to_drop)
# Out:
# 254

# %%
song_data = pd.read_csv("output/data/million_song_data_with_features.csv")

# %%
song_data=song_data.drop(indices_to_drop)

# %%
song_data.to_csv("output/data/million_song_data_with_features_English.csv", index=False, header=True)

# %%
new_data = pd.read_csv("output/data/million_song_data_with_features_English.csv")

# %%
new_data.head()
# Out:
#   artist              song                                   link  \
# 0   ABBA  Andante, Andante  /a/abba/andante+andante_20002708.html
# 1   ABBA    As Good As New   /a/abba/as+good+as+new_20003033.html
# 2   ABBA              Bang             /a/abba/bang_20598415.html
# 3   ABBA         Cassandra        /a/abba/cassandra_20002811.html
# 4   ABBA        Chiquitita       /a/abba/chiquitita_20002978.html
#
#                                                 text                      id  \
# 0  Take it easy with me, please  \nTouch me gentl...  1JnHZagDFvrT2lx4QovSOo
# 1  I'll never know why I had to go  \nWhy I had t...  71or1G6CbfIttRDnBnTTAL
# 2  Making somebody happy is a question of give an...  5jfZEsdQMAaoeDLib5rLu4
# 3  Down in the street they're all singing and sho...  5Qawpf7n2qDIcTaBDK67Sb
# 4  Chiquitita, tell me what's wrong  \nYou're enc...  762B4bOcXF7I2Y8UlKTyTy
#
#    explicit  danceability  energy  key  loudness  ...  instrumentalness  \
# ...

# %%
new_data.iloc[130:140]
# Out:
#         artist                 song  \
# 130  Aerosmith       One Way Street
# 131  Aerosmith      Outta Your Head
# 132  Aerosmith        Pandora's Box
# 133  Aerosmith   Permanent Vacation
# 134  Aerosmith                 Pink
# 135  Aerosmith    Prelude To Joanie
# 136  Aerosmith  Push Comes To Shove
# 137  Aerosmith             Rag Doll
# 138  Aerosmith   Rats In The Cellar
# 139  Aerosmith    Rattlesnake Shake
#
#                                                link  \
# 130       /a/aerosmith/one+way+street_20004409.html
# 131      /a/aerosmith/outta+your+head_20004307.html
# 132         /a/aerosmith/pandoras+box_20004410.html
# 133   /a/aerosmith/permanent+vacation_20004438.html
# 134                 /a/aerosmith/pink_20004373.html
# 135    /a/aerosmith/prelude+to+joanie_20004459.html
# 136  /a/aerosmith/push+comes+to+shove_20004203.html
# 137             /a/aerosmith/rag+doll_20004439.html
# 138   /a/aerosmith/rats+in+the+cellar_20004469.html
# ...
